# %%
# !pip install streamlit -q
# !npm install localtunnel
# Out:
# m#########.........] - idealTree: timing idealTree Completed in 86ms
# up to date, audited 23 packages in 571ms
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.

# %%
# %%writefile app.py

import cv2
import numpy as np
import streamlit as st
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.applications.mobilenet_v2 import MobileNetV2,preprocess_input as mobilenet_v2_preprocess_input

model = tf.keras.models.load_model("enter the path of model.h5")
### load file
uploaded_file = st.file_uploader("Choose a image file", type="jpg")

map_dict = {0: 'glioma',
            1: 'meningioma',
            2: 'no tumor',
            3: 'pituitary',
            }


if uploaded_file is not None:
    # Convert the file to an opencv image.
    file_bytes = np.asarray(bytearray(uploaded_file.read()), dtype=np.uint8)
    img = cv2.imdecode(file_bytes, 1)
    img = cv2.resize(img,(150,150))
    img_array = np.array(img)
    img_array.shape
    st.image(img, channels="RGB")
    img_array = img_array.reshape(1,150,150,3)
    
    Genrate_pred = st.button("Generate Prediction")    
    if Genrate_pred:
        prediction = model.predict(img_array).argmax()
        st.title("Predicted Label for the image is {}".format(map_dict [prediction]))
# Out:
# Overwriting app.py

# %%
# !curl ipv4.icanhazip.com
# Out:
# 34.31.13.248

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.19.2.2:8501
#   External URL: http://34.31.13.248:8501
#
# your url is: https://gold-bikes-end.loca.lt
# 2024-04-04 00:50:20.453701: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-04 00:50:20.453759: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-04 00:50:20.455453: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712191849.907849     335 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 2024-04-04 00:51:08.742 Uncaught app exception
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/layers/layer.py", line 224, in build_wrapper
#     original_build_method(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py", line 177, in build
#     x = layer(x)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 123, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/backend/common/name_scope.py", line 50, in __exit__
#     name_scope_stack.pop()
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 542, in _run_script
#     exec(code, module.__dict__)
#   File "/kaggle/working/app.py", line 10, in <module>
#     model = tf.keras.models.load_model("/kaggle/input/cnnh5file/cnnbtfinal_newest.h5")
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_api.py", line 183, in load_model
#     return legacy_h5_format.load_model_from_hdf5(filepath)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/legacy/saving/legacy_h5_format.py", line 133, in load_model_from_hdf5
#     model = saving_utils.model_from_config(
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/legacy/saving/saving_utils.py", line 85, in model_from_config
#     return serialization.deserialize_keras_object(
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/legacy/saving/serialization.py", line 495, in deserialize_keras_object
#     deserialized_obj = cls.from_config(
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py", line 336, in from_config
#     model.add(layer)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py", line 117, in add
#     self._maybe_rebuild()
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py", line 136, in _maybe_rebuild
#     self.build(input_shape)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/layers/layer.py", line 223, in build_wrapper
#     with backend.name_scope(obj.name, caller=obj):
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/core.py", line 291, in __exit__
#     super().__exit__(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/backend/common/name_scope.py", line 50, in __exit__
#     name_scope_stack.pop()
# IndexError: pop from empty list
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# ^C
#   Stopping...
